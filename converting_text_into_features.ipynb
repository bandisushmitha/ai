# %% [markdown]
# <a href="https://colab.research.google.com/github/bandisushmitha/ai/blob/main/converting_text_into_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Text="I amm learning NLP"

# %%
import pandas as pd
pd.get_dummies(Text.split())
# Out:
#        I    NLP    amm  learning
# 0   True  False  False     False
# 1  False  False   True     False
# 2  False  False  False      True
# 3  False   True  False     False

# %%
text=["i love NLP and i will learn NLP in 2 months"]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()
vectorizer.fit(text)
vector=vectorizer.transform(text)

# %%
print(vectorizer.vocabulary_)
print(vector.toarray())
# Out:
# {'love': 3, 'nlp': 5, 'and': 0, 'will': 6, 'learn': 2, 'in': 1, 'months': 4}
# [[1 1 1 1 1 2 1]]

# %%
print(vector)
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	1
#   (0, 5)	2
#   (0, 6)	1

# %%
CountVectorizer?

# %%
df=pd.DataFrame(data=vector.toarray(),columns=vectorizer.get_feature_names_out())
df
# Out:
#    and  in  learn  love  months  nlp  will
# 0    1   1      1     1       1    2     1
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# ...

# %%
import nltk
nltk.download('punkt_tab')
from textblob import TextBlob
TextBlob(text[0]).ngrams(1)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [WordList(['i']),
#  WordList(['love']),
#  WordList(['NLP']),
#  WordList(['and']),
#  WordList(['i']),
#  WordList(['will']),
#  WordList(['learn']),
#  WordList(['NLP']),
#  WordList(['in']),
#  WordList(['2']),
#  WordList(['months'])]

# %%
TextBlob(text[0]).ngrams(2)
# Out:
# [WordList(['i', 'love']),
#  WordList(['love', 'NLP']),
#  WordList(['NLP', 'and']),
#  WordList(['and', 'i']),
#  WordList(['i', 'will']),
#  WordList(['will', 'learn']),
#  WordList(['learn', 'NLP']),
#  WordList(['NLP', 'in']),
#  WordList(['in', '2']),
#  WordList(['2', 'months'])]

# %%
TextBlob(text[0]).ngrams(3)
# Out:
# [WordList(['i', 'love', 'NLP']),
#  WordList(['love', 'NLP', 'and']),
#  WordList(['NLP', 'and', 'i']),
#  WordList(['and', 'i', 'will']),
#  WordList(['i', 'will', 'learn']),
#  WordList(['will', 'learn', 'NLP']),
#  WordList(['learn', 'NLP', 'in']),
#  WordList(['NLP', 'in', '2']),
#  WordList(['in', '2', 'months'])]

# %%
TextBlob(text[0]).ngrams(4)
# Out:
# [WordList(['i', 'love', 'NLP', 'and']),
#  WordList(['love', 'NLP', 'and', 'i']),
#  WordList(['NLP', 'and', 'i', 'will']),
#  WordList(['and', 'i', 'will', 'learn']),
#  WordList(['i', 'will', 'learn', 'NLP']),
#  WordList(['will', 'learn', 'NLP', 'in']),
#  WordList(['learn', 'NLP', 'in', '2']),
#  WordList(['NLP', 'in', '2', 'months'])]

# %%
Text=["The quick brown fox jumped over the lazy dog.","The dog,","The fox."]

# %%
# !pip uninstall scikit-learn
# !pip install scikit-learn
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/scikit_learn-1.6.1.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0
#     /usr/local/lib/python3.11/dist-packages/sklearn/*
# Proceed (Y/n)? y
#   Successfully uninstalled scikit-learn-1.6.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 64.4 MB/s eta 0:00:00
# ...

# %%
# !pip install -U scikit-learn
